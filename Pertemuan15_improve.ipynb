# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors
from sklearn import metrics

np.random.seed(0)
X = np.sort(5 * np.random.rand(40, 1), axis=0)
T = np.linspace(0, 5, 500)[:, np.newaxis]
y = np.sin(X).ravel()

# Add noise to targets
y[::5] += 1 * (0.5 - np.random.rand(8))

# %%
X.shape
# Out:
# (40, 1)

# %%
T.shape
# Out:
# (500, 1)

# %%
y.shape
# Out:
# (40,)

# %%
n_neighbors = 5

for i, weights in enumerate(["uniform", "distance"]):
    knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
    y_ = knn.fit(X, y).predict(T)
# print("Accuracy:", metrics.accuracy_score(predict, ))

# %%
    plt.subplot(2, 1, i + 1)
    plt.scatter(X, y, color="darkorange", label="data")
    plt.plot(T, y_, color="navy", label="prediction")
    plt.axis("tight")
    plt.legend()
    plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, weights))

plt.tight_layout()
plt.show()

# %%
#Melihat korelasi antardata menggunakan heatmap
plt.figure(figsize=(16, 9))
sns.heatmap(df_copy.corr(), vmin=-1, vmax=1, annot=True, cmap="PuRd")

# Save Plot
plt.savefig("corr_heatmap.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11288\623559128.py in <module>
#       1 #Melihat korelasi antardata menggunakan heatmap
#       2 plt.figure(figsize=(16, 9))
# ----> 3 sns.heatmap(df_copy.corr(), vmin=-1, vmax=1, annot=True, cmap="PuRd")
#       4
#       5 # Save Plot
#
# NameError: name 'sns' is not defined
