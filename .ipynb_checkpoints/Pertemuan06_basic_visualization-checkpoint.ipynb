# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('../data/canada.xlsx', 
                   sheet_name='Canada by Citizenship', 
                   skiprows=range(20),
                  skipfooter=2)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.shape
# Out:
# (195, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df.columns.values
# Out:
# array(['Continent', 'Region', 'DevName', 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 'Total'], dtype=object)

# %% [markdown]
# Tipe data utama di pandas adalah
# * float
# * int
# * category
# * bool
# * datetime64[ns] and datetime64[ns, tz]
# * timedelta[ns]
# * category (in >= 0.15.0)
# * object (string)
#
# * in addition have item sizes, eg. int64, int32

# %% [markdown]
# ### Delete columns
# Hapus kolom-kolom yang tidak diperlukan untuk analisis. yaitu,

# %%
df.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10936\1126513115.py in <module>
# ----> 1 df.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head(2)
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %% [markdown]
# ### Ubah Nama Kolom

# %%
df.rename(columns={'OdName' : 'Country',
                  'AreaName' : 'Continent',
                  'RegName' : 'Region'}, inplace=True)

# %%
df.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %% [markdown]
# ### Add columns

# %%
df['Total'] = df.sum(axis=1)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10936\2759960331.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.sum(axis=1)

# %% [markdown]
# ### Memeriksa Objek Null

# %%
df.isnull().sum()
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# dtype: int64

# %% [markdown]
# ### Lihat deskripsi statistik kolom

# %%
df.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %% [markdown]
# ## Pandas: Indexing and Selection

# %% [markdown]
# ### Select Column
# Ada dua cara untuk memfilter kolom di pandas.
# * Metode 1: cara cepat dan mudah, tetapi hanya berfungsi jika nama kolom TIDAK memiliki spasi
#
# df.column_name
#
#     (return series)
#
# * Metode 2
#
# df['column']
#
#     (return series)
#
# df[['colums 1', 'colums 2']]
#
#     (return dataframe)

# %%
df.Country
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: Country, Length: 195, dtype: object

# %%
df[['Country', 1980, 1981, 1982, 1984]]
# Out:
#             Country  1980  1981  1982  1984
# 0       Afghanistan    16    39    39    71
# 1           Albania     1     0     0     0
# 2           Algeria    80    67    71    63
# 3    American Samoa     0     1     0     0
# 4           Andorra     0     0     0     0
# ..              ...   ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162  7583
# 191  Western Sahara     0     0     0     0
# 192           Yemen     1     2     1     0
# 193          Zambia    11    17    11    16
# 194        Zimbabwe    72   114   102    32
#
# [195 rows x 5 columns]

# %% [markdown]
# ### Select Row

# %% [markdown]
# Sebelum itu, perhatikan bahwa index dari dataset adalah rentang numerik dari 0 hingga 194. Hal ini membuatnya sangat sulit untuk melakukan kueri berdasarkan negara tertentu. Misalnya untuk mencari data dari Jepang, kita perlu mengetahui index yang sesuai.
#
# Hal ini dapat diperbaiki dengan mudah, dengan menyetel kolom 'Country sebagai index.

# %%
df.set_index('Country', inplace=True)

# %%
# Remove the name of the index
df.index.name = None

# %% [markdown]
# Mari kita lihat jumlah imigram dari Jepang

# %%
# 1. The full row data
print(df.loc['Japan'])

# Alternative methods
# print(df.iloc[87])
# print(df[df.index == 'Japan'].T.squeeze())
# Out:
# Continent                 Asia
# Region            Eastern Asia
# DevName      Developed regions
# 1980                       701
# 1981                       756
# 1982                       598
# 1983                       309
# 1984                       246
# 1985                       198
# 1986                       248
# 1987                       422
# 1988                       324
# 1989                       494
# 1990                       379
# 1991                       506
# 1992                       605
# 1993                       907
# 1994                       956
# 1995                       826
# 1996                       994
# 1997                       924
# 1998                       897
# 1999                      1083
# 2000                      1010
# 2001                      1092
# 2002                       806
# 2003                       817
# 2004                       973
# 2005                      1067
# 2006                      1212
# ...

# %%
# 2. for year 2013
print(df.loc['Japan', 2013])

# Alternative method
# print(df.iloc[87, 36]) # year 2013 is the last column, with a positional index of 36
# Out:
# 982

# %%
# 3. for years 1980 to 1985
print(df.loc['Japan', [1980, 1981, 1982, 1983, 1984, 1985]])

# Alternative method
# print(df.iloc[87. []])
# Out:
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246
# 1985    198
# Name: Japan, dtype: object

# %% [markdown]
# ### Ubah nama kolom jadi string

# %%
df.columns = list(map(str, df.columns))

# %%
df.columns
# Out:
# Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
# Buat variabel baru untuk digunakan pada plot nantinya
years = list(map(str, range(1980, 2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# ### Filtering Based on Criteria

# %%
# Menampilkan data dari negara asia

# 1. Create the condition boolean series
condition = df['Continent'] == 'Asia'
print (condition)
# Out:
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam           True
# Western Sahara    False
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Name: Continent, Length: 195, dtype: bool

# %%
# 2. Pass this condition into the dataFrame
df[condition]
# Out:
#                                                Continent              Region  \
# Afghanistan                                         Asia       Southern Asia
# Armenia                                             Asia        Western Asia
# Azerbaijan                                          Asia        Western Asia
# Bahrain                                             Asia        Western Asia
# Bangladesh                                          Asia       Southern Asia
# Bhutan                                              Asia       Southern Asia
# Brunei Darussalam                                   Asia  South-Eastern Asia
# Cambodia                                            Asia  South-Eastern Asia
# China                                               Asia        Eastern Asia
# China, Hong Kong Special Administrative Region      Asia        Eastern Asia
# China, Macao Special Administrative Region          Asia        Eastern Asia
# ...

# %%
# Use multiple criteria
df[(df['Continent'] == 'Asia') & (df['Region'] == 'Southern Asia')]
# Notes, 'and' and 'or' in pandas is & and |
# Don't forget to enclose the two condition in parentheses
# Out:
#                            Continent         Region             DevName  1980  \
# Afghanistan                     Asia  Southern Asia  Developing regions    16
# Bangladesh                      Asia  Southern Asia  Developing regions    83
# Bhutan                          Asia  Southern Asia  Developing regions     0
# India                           Asia  Southern Asia  Developing regions  8880
# Iran (Islamic Republic of)      Asia  Southern Asia  Developing regions  1172
# Maldives                        Asia  Southern Asia  Developing regions     0
# Nepal                           Asia  Southern Asia  Developing regions     1
# Pakistan                        Asia  Southern Asia  Developing regions   978
# Sri Lanka                       Asia  Southern Asia  Developing regions   185
#
#                             1981  1982  1983  1984  1985  1986  ...   2005  \
# Afghanistan                   39    39    47    71   340   496  ...   3436
# ...

# %% [markdown]
# ### Tinjau perubahan

# %%
print ('data dimensions:', df.shape)
print('Kolom-kolom data: ', df.columns)
# Out:
# data dimensions: (195, 38)
# Kolom-kolom data:  Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %% [markdown]
# # Visualization using Matplotlib

# %% [markdown]
# ### Matplotlib.Pyplot
# Matplotlin.pyplot adalah kumpulan fungsi gaya perintah yang membuat matplotlib berfungsi seperti MATLAB.

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Optional key to style matplotlib
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
mpl.style.use(['ggplot'])

# %% [markdown]
# #### Plotting in Pandas
# Pandas memiliki matplotlib bawaan yang dapat digunakan untuk plot. Caranya tambahkan .plot() ke series atau dataframe.
#
# df.plot()

# %% [markdown]
# ### Line Plots

# %%
haiti = df.loc['Haiti', years]
haiti.head(2)
# Out:
# 1980    1666
# 1981    3692
# Name: Haiti, dtype: object

# %%
haiti.plot();

# %%
# Membuat label
haiti.index = haiti.index.map(int)

haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigration')
plt.xlabel('Years')

plt.show();

# %%
# Membuat label
haiti.index = haiti.index.map(int)

haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigration')
plt.xlabel('Years')

plt.text(2000, 6000, '2010 Earthquake')
plt.show();

# %%
china_india = df.loc[['China', 'India'], years]
china_india
# Out:
#        1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# China  5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India  8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#         2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# China  36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India  28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
china_india.plot(kind='line');

# %% [markdown]
# Index diproses sebagai sumbu x
#
# kolom pada sumbu y

# %%
# Transpose
df_ci = china_india.transpose()
df_ci.head(2)
# Out:
#       China  India
# 1980   5123   8880
# 1981   6682   8670

# %%
df_ci.plot(kind='line');
plt.title('Imigranst from China and India')
plt.ylabel('Number of Imigrants')
plt.xlabel('Years')
plt.show;

# %% [markdown]
# Dari plot diatas, kita dapat mengamati bahwa China dan India memiliki tren imigrasi yang sangat mirip selama bertahun-tahun.

# %% [markdown]
# ### Question: Compare the trend of top 5 countries that distributed the most immigration to Canada

# %%
df.sort_values(by='Total', ascending=False, axis=0, inplace=True)

df_top5 = df.head(5)

df_top5 = df_top5[years].transpose()

df_top5.index = df_top5.index.map(int)

df_top5.plot(kind='line', figsize=(14, 8))

plt.title('Immigration trend of top 5 Countries')
plt.ylabel('Number of imigration')
plt.xlabel('Years')

plt.show();

# %% [markdown]
# ## Area plots

# %%
# Ubah tipe data ke integer
df_top5.index = df_top5.index.map(int)

df_top5.plot(kind='area', alpha=0.20, stacked=False , figsize=(20, 10))

plt.title('Immigration trend of top 5 Countries')
plt.ylabel('Number of imigration')
plt.xlabel('Years')

plt.show();

# %% [markdown]
# ## Two tipes of plotting
#
# Ada dua gaya dalam membuat plot di matplotliba.
# * 1. Scripting layer (procedural method), menggunakan matplotlib.pyplot as plt
# * 2. Artist layer (Object oriented method), using axes

# %%
# option 2, object oriented
ax = df_top5.plot(kind='area', alpha=0.25, figsize=(20,10));

ax.set_title('Immigration trend of top 5 Countries')
ax.set_ylabel('Number of imigration')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ### Question: create area plot of the 5 countries that contributed the least to immigration to Canada from 1980 to 2013

# %%
df.sort_values(by='Total', ascending=False, axis=0, inplace=True)

df_least5 = df.tail(5)
# df_least2 = df_can.tail(5)
df_least5 = df_least5[years].transpose()

df_least5.plot(kind='area', alpha=0.20, stacked=True , figsize=(20, 10))

plt.title('Immigration trend of top 5 Countries')
plt.ylabel('Number of imigration')
plt.xlabel('Years')

plt.show();

# %% [markdown]
# ### Histogram

# %% [markdown]
# ### Question: What is the population of new immigrants from the various to Canada in 2013?

# %%
df['2013'].head()
# Out:
# Country
# India                                                   33087
# China                                                   34129
# United Kingdom of Great Britain and Northern Ireland     5827
# Philippines                                             29544
# Pakistan                                                12603
# Name: 2013, dtype: int64

# %%
# np histogram return 2 values
count, bin_edges = np.histogram(df['2013'])

print(count) # frequency count
print(bin_edges) # bin ranges, default = 10 bins
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df['2013'].plot(kind='hist', figsize=(8, 5))
plt.title('Immigration from 195 Countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Numbers of imigrants')

plt.show();

# %%
# Memasukkan xticks berisi daftar ukuran bin
df['2013'].plot(kind='hist', figsize=(8, 5), xticks=bin_edges)
plt.title('Immigration from 195 Countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Numbers of imigrants')

plt.show();

# %% [markdown]
# ### question: what the imigration distribution for Denmark, Norway and Sweden for years 1980 - 2013

# %%
df.loc[['Denmark', 'Norway', 'Sweden'], years]
# Out:
#          1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                              ...
# Denmark   272   293   299   106    93    73    93   109   129   129  ...
# Norway    116    77   106    51    31    54    56    80    73    76  ...
# Sweden    281   308   222   176   128   158   187   198   171   182  ...
#
#          2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Denmark    89    62   101    97   108    81    92    93    94    81
# Norway     73    57    53    73    66    75    46    49    53    59
# Sweden    129   205   139   193   165   167   159   134   140   140
#
# [3 rows x 34 columns]

# %%
# generate histogram
df.loc[['Denmark', 'Norway', 'Sweden'], years].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Kelihatannya tidak benar, malah yang di plot adalah distribusi frekuensi untuk years.
#
# Kita bisa perbaiki dengan mentranspose dataset

# %%
df_t = df.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
df_t.head()
# Out:
# Country  Denmark  Norway  Sweden
# 1980         272     116     281
# 1981         293      77     308
# 1982         299     106     222
# 1983         106      51     176
# 1984          93      31     128

# %%
df_t.plot(kind='hist', figsize=(20, 6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Make the plot esthetic

# Get x-tick values
count, bin_edges = np.histogram(df_t, 15)

df_t.plot(kind='hist', figsize=(20, 6), bins=15, alpha=0.6, xticks=bin_edges,
                                color=['coral', 'darkslateblue', 'mediumseagreen'] )

plt.title('Histogram of imigration from Denmark, Norway and Sweden')
plt.ylabel('Number of years')
plt.xlabel('Number of imigrants')
# Out:
# Text(0.5, 0, 'Number of imigrants')

# %% [markdown]
# Jika tidak ingin plots saling tumpang tindih, kita dapat menumpuknya dengan parameter stacked.

# %%
count, bin_edges = np.histogram(df_t, 15)
xmin = bin_edges[0] - 10
xmax = bin_edges[-1] + 10
df_t.plot(kind='hist', 
          figsize=(20, 6), 
          bins=15, 
          alpha=0.6, xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen'],
          stacked=True,
          xlim=(xmin, xmax))

plt.title('Histogram of imigration from Denmark, Norway and Sweden')
plt.ylabel('Number of years')
plt.xlabel('Number of imigrants')
# Out:
# Text(0.5, 0, 'Number of imigrants')

# %% [markdown]
# ### Question: Display the immigration distribution for Greece, Albania, and Indonesia

# %%
df_ind = df.loc[['Greece', 'Albania', 'Bulgaria'], years]
df_indt = df_ind.transpose()

# %%
count, bin_edges = np.histogram(df_indt, 15)
xmin = bin_edges[0] - 10
xmax = bin_edges[-1] + 10
df_indt.plot(kind='hist', 
          figsize=(20, 6), 
          bins=15, 
          alpha=0.6, xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen'],
#           stacked=True,
          xlim=(xmin, xmax))

plt.title('Histogram of imigration from Greece, Albania and Indonesia')
plt.ylabel('Number of years')
plt.xlabel('Number of imigrants')
# Out:
# Text(0.5, 0, 'Number of imigrants')

# %% [markdown]
# ## Bar chart
#
# ### Question: Compare the number of Icelandic immigratnts (country='Iceland to Canada

# %%
df_iceland = df.loc['Iceland', years]
df_iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
df_iceland.plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
# Menambahkan anotasi
df_iceland.plot(kind='bar', figsize=(10,6))


# Panah
plt.annotate('', xy=(32, 70), xytext=(28, 20), 
             xycoords='data', arrowprops=dict(arrowstyle='->',
            connectionstyle='arc3', color='blue', lw=2)
            )

# Teks
plt.annotate('2008 - 2011 Financial Crisis',
            xy=(28, 30),
            rotation=72.5,
            va='bottom',
            ha='left')

plt.show();

# %% [markdown]
# ### Horizontal bar plot

# %% [markdown]
# ### Question:  Create a plot to showing the total number of imigrants to Canada from the top 15 countries

# %%
df.sort_values(by='Total', ascending=True, inplace=True)
df_top15 = df['Total'].tail(15)
df_top15
# Out:
# Country
# Romania                                                  93585
# Viet Nam                                                 97146
# Jamaica                                                 106431
# France                                                  109091
# Lebanon                                                 115359
# Poland                                                  139241
# Republic of Korea                                       142581
# Sri Lanka                                               148358
# Iran (Islamic Republic of)                              175923
# United States of America                                241122
# Pakistan                                                241600
# Philippines                                             511391
# United Kingdom of Great Britain and Northern Ireland    551500
# China                                                   659962
# India                                                   691904
# ...

# %%
df_top15.plot(kind='barh', figsize=(12, 12),
             color='steelblue')
plt.xlabel('Number of Immigrants')
plt.ylabel('Countries')
plt.title('Top 15 Countries')

plt.show();

# %% [markdown]
# ### Pie Chart

# %%
df_continents = df.groupby('Continent', axis=0).sum()
df_continents
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    2005  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   27523
# Asia                             28739  43203  47454  60256  ...  159253
# Europe                           24370  46698  54726  60893  ...   35955
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24747
# ...

# %%
df_continents['Total'].plot(kind='pie',
                           figsize=(5, 6),
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True)

plt.title('Immigration to Canada')
plt.axis('equal')

plt.show();

# %%
color_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1]

df_continents['Total'].plot(kind='pie',
                           figsize=(15, 6),
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True,
                           labels=None,
                           pctdistance=1.12,
                           colors=color_list,
                           explode=explode_list)
plt.title('Immigration to Canada', y=1.12)
plt.axis('equal')

# add legend
plt.legend(labels=df_continents.index, loc='upper left')
plt.show();

# %% [markdown]
# ### Box plots

# %%
df_japan = df.loc[['Japan'], years].transpose()
df_japan.head()
# Out:
# Country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246

# %%
df_japan.plot(kind='box', figsize=(8, 6))

plt.title('Boxplots of Japanese Immigration')
plt.ylabel('Number of imigrants')

plt.show();

# %%
df_ci.describe()
# Out:
#               China         India
# count     34.000000     34.000000
# mean   19410.647059  20350.117647
# std    13568.230790  10007.342579
# min     1527.000000   4211.000000
# 25%     5512.750000  10637.750000
# 50%    19945.000000  20235.000000
# 75%    31568.500000  28699.500000
# max    42584.000000  36210.000000

# %%
df_ci.plot(kind='box', figsize=(8, 6))

plt.title('Boxplots of China India Immigration')
plt.ylabel('Number of imigrants')

plt.show();

# %%
df_ci.plot(kind='box', figsize=(8, 6), vert=False, color='limegreen')

plt.title('Boxplots of China India Immigration')
plt.ylabel('Number of imigrants')

plt.show();

# %% [markdown]
# ### Scatter plot

# %%
df_tot = pd.DataFrame(df[years].sum(axis=0))

df_tot.index = map(int, df_tot.index)

df_tot.reset_index(inplace=True)

df_tot.columns = ['year', 'total']

df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10,6), color='darkblue')

plt.title('Total imigration')
plt.xlabel('Year')
plt.ylabel('Number of imigration')

plt.show();
